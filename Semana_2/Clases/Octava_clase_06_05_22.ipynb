# %%
import pandas as pd

# %%
filename='/Users/matiasinostrozacifuentes/Desktop/python_intro/DataScience_Unilever/Semana_2/Data/202103-divvy-tripdata_new.csv'
dt1=pd.read_csv(filename)

# %%
filename1='/Users/matiasinostrozacifuentes/Desktop/python_intro/DataScience_Unilever/Semana_2/Data/202104-divvy-tripdata_new.csv'
dt2=pd.read_csv(filename1)

# %%
filename2=''
dt3=pd.read_csv(filename2)

# %% [markdown]
# primeras impresiones de los dataset

# %%
dt1.head(10)
# Out:
#             ride_id  rideable_type        started_at          ended_at  \
# 0  CFA86D4455AA1030   classic_bike  16/03/2021 08:32  16/03/2021 08:36
# 1  30D9DC61227D1AF3   classic_bike  28/03/2021 01:26  28/03/2021 01:36
# 2  846D87A15682A284   classic_bike  11/03/2021 21:17  11/03/2021 21:33
# 3  994D05AA75A168F2   classic_bike  11/03/2021 13:26  11/03/2021 13:55
# 4  DF7464FBE92D8308   classic_bike  21/03/2021 09:09  21/03/2021 09:27
# 5  CEBA8516FD17F8D8   classic_bike  20/03/2021 11:08  20/03/2021 11:29
# 6  297268586B79588B   classic_bike  20/03/2021 14:10  20/03/2021 14:22
# 7  F39301858B6077DD  electric_bike  23/03/2021 07:56  23/03/2021 08:05
# 8  D297F199D875BABE  electric_bike  31/03/2021 15:31  31/03/2021 15:35
# 9  36B877141175ED7E   classic_bike  11/03/2021 17:37  11/03/2021 17:52
#
#              start_station_name start_station_id  \
# 0  Humboldt Blvd & Armitage Ave            15651
# 1  Humboldt Blvd & Armitage Ave            15651
# ...

# %%
dt2.head(10)
# Out:
#             ride_id  rideable_type        started_at          ended_at  \
# 0  6C992BD37A98A63F   classic_bike  12/04/2021 18:25  12/04/2021 18:56
# 1  1E0145613A209000    docked_bike  27/04/2021 17:27  27/04/2021 18:31
# 2  E498E15508A80BAD    docked_bike  03/04/2021 12:42  07/04/2021 11:40
# 3  1887262AD101C604   classic_bike  17/04/2021 09:17  17/04/2021 09:42
# 4  C123548CAB2A32A5    docked_bike  03/04/2021 12:42  03/04/2021 14:13
# 5  097E76F3651B1AC1   classic_bike  25/04/2021 18:43  25/04/2021 18:43
# 6  53C38EB01E6FA5C4   classic_bike  03/04/2021 16:28  03/04/2021 16:29
# 7  D53AC014EFD6E2BA  electric_bike  06/04/2021 16:35  06/04/2021 17:00
# 8  6E2F7CA1FA9E0AFB   classic_bike  12/04/2021 15:22  12/04/2021 16:15
# 9  04218447AAC80BD1   classic_bike  24/04/2021 15:04  24/04/2021 15:06
#
#          start_station_name start_station_id              end_station_name  \
# 0     State St & Pearson St     TA1307000061  Southport Ave & Waveland Ave
# ...

# %%
dt1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228496 entries, 0 to 228495
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             228496 non-null  object
#  1   rideable_type       228496 non-null  object
#  2   started_at          228496 non-null  object
#  3   ended_at            228496 non-null  object
#  4   start_station_name  213648 non-null  object
#  5   start_station_id    213648 non-null  object
#  6   end_station_name    211769 non-null  object
#  7   end_station_id      211769 non-null  object
#  8   start_lat           228496 non-null  float64
#  9   start_lng           228496 non-null  float64
#  10  end_lat             228329 non-null  float64
#  11  end_lng             228329 non-null  float64
#  12  member_casual       228496 non-null  object
#  13  ride_length         228496 non-null  object
#  14  day_of_week_start   228496 non-null  int64
# ...

# %%
dt2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337230 entries, 0 to 337229
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             337230 non-null  object
#  1   rideable_type       337230 non-null  object
#  2   started_at          337230 non-null  object
#  3   ended_at            337230 non-null  object
#  4   start_station_name  311174 non-null  object
#  5   start_station_id    311174 non-null  object
#  6   end_station_name    309056 non-null  object
#  7   end_station_id      309056 non-null  object
#  8   start_lat           337230 non-null  float64
#  9   start_lng           337230 non-null  float64
#  10  end_lat             336963 non-null  float64
#  11  end_lng             336963 non-null  float64
#  12  member_casual       337230 non-null  object
#  13  ride_length         337230 non-null  object
#  14  day_of_week_start   337230 non-null  int64
# ...

# %% [markdown]
# Revisando por tipo de bicicleta, porcentaje del total

# %%
dt1.groupby(['rideable_type'])[['rideable_type']].count()/dt1['rideable_type'].count()*100
# Out:
#                rideable_type
# rideable_type
# classic_bike       66.760468
# docked_bike         6.852199
# electric_bike      26.387333

# %%
dt2.groupby(['rideable_type'])[['rideable_type']].count()/dt2['rideable_type'].count()*100
# Out:
#                rideable_type
# rideable_type
# classic_bike       63.641728
# docked_bike         7.328529
# electric_bike      29.029742

# %% [markdown]
# reemplazando nulos

# %%
for i in dt1:
    NaN=dt1[i].isna().sum()
    print(i,NaN)
# Out:
# ride_id 0
# rideable_type 0
# started_at 0
# ended_at 0
# start_station_name 14848
# start_station_id 14848
# end_station_name 16727
# end_station_id 16727
# start_lat 0
# start_lng 0
# end_lat 167
# end_lng 167
# member_casual 0
# ride_length 0
# day_of_week_start 0
# day_of_week_end 0
# mode 228495

# %%
for i in dt1:
    NaN=dt2[i].isna().sum()
    print(i,NaN)
# Out:
# ride_id 0
# rideable_type 0
# started_at 0
# ended_at 0
# start_station_name 26056
# start_station_id 26056
# end_station_name 28174
# end_station_id 28174
# start_lat 0
# start_lng 0
# end_lat 267
# end_lng 267
# member_casual 0
# ride_length 0
# day_of_week_start 0
# day_of_week_end 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %% [markdown]
# Tratando NaN

# %%
#para dt1
for i in dt1:
    print(i,dt1[i].isna().sum() )
# Out:
# ride_id 0
# rideable_type 0
# started_at 0
# ended_at 0
# start_station_name 14848
# start_station_id 14848
# end_station_name 16727
# end_station_id 16727
# start_lat 0
# start_lng 0
# end_lat 167
# end_lng 167
# member_casual 0
# ride_length 0
# day_of_week_start 0
# day_of_week_end 0
# mode 228495

# %%
dt_prueba=dt1

# %%
dt_prueba['start_station_name'].dropna()
# Out:
# 0         Humboldt Blvd & Armitage Ave
# 1         Humboldt Blvd & Armitage Ave
# 2                Shields Ave & 28th Pl
# 3          Winthrop Ave & Lawrence Ave
# 4             Glenwood Ave & Touhy Ave
#                       ...
# 228490      Larrabee St & Armitage Ave
# 228491           Michigan Ave & Oak St
# 228492        Kingsbury St & Kinzie St
# 228493           Michigan Ave & Oak St
# 228494        Kingsbury St & Kinzie St
# Name: start_station_name, Length: 213648, dtype: object

# %%
del dt_prueba['mode']
dt_prueba
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mode'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
dt_prueba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228496 entries, 0 to 228495
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             228496 non-null  object
#  1   rideable_type       228496 non-null  object
#  2   started_at          228496 non-null  object
#  3   ended_at            228496 non-null  object
#  4   start_station_name  213648 non-null  object
#  5   start_station_id    213648 non-null  object
#  6   end_station_name    211769 non-null  object
#  7   end_station_id      211769 non-null  object
#  8   start_lat           228496 non-null  float64
#  9   start_lng           228496 non-null  float64
#  10  end_lat             228329 non-null  float64
#  11  end_lng             228329 non-null  float64
#  12  member_casual       228496 non-null  object
#  13  ride_length         228496 non-null  object
#  14  day_of_week_start   228496 non-null  int64
# ...

# %%
dt_prueba['start_station_name']=dt_prueba.loc[: ,'start_station_name'].fillna(value='No informado')

# %%
dt_prueba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228496 entries, 0 to 228495
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             228496 non-null  object
#  1   rideable_type       228496 non-null  object
#  2   started_at          228496 non-null  object
#  3   ended_at            228496 non-null  object
#  4   start_station_name  228496 non-null  object
#  5   start_station_id    213648 non-null  object
#  6   end_station_name    211769 non-null  object
#  7   end_station_id      211769 non-null  object
#  8   start_lat           228496 non-null  float64
#  9   start_lng           228496 non-null  float64
#  10  end_lat             228329 non-null  float64
#  11  end_lng             228329 non-null  float64
#  12  member_casual       228496 non-null  object
#  13  ride_length         228496 non-null  object
#  14  day_of_week_start   228496 non-null  int64
# ...

# %%
dt_prueba
# Out:
#                  ride_id  rideable_type        started_at          ended_at  \
# 0       CFA86D4455AA1030   classic_bike  16/03/2021 08:32  16/03/2021 08:36
# 1       30D9DC61227D1AF3   classic_bike  28/03/2021 01:26  28/03/2021 01:36
# 2       846D87A15682A284   classic_bike  11/03/2021 21:17  11/03/2021 21:33
# 3       994D05AA75A168F2   classic_bike  11/03/2021 13:26  11/03/2021 13:55
# 4       DF7464FBE92D8308   classic_bike  21/03/2021 09:09  21/03/2021 09:27
# ...                  ...            ...               ...               ...
# 228491  9397BDD14798A1BA    docked_bike  20/03/2021 14:58  20/03/2021 17:22
# 228492  BBBEB8D51AAD40DA   classic_bike  02/03/2021 11:35  02/03/2021 11:43
# 228493  637FF754DA0BD9E1   classic_bike  09/03/2021 11:07  09/03/2021 11:49
# 228494  F8F43A0B978A7A35   classic_bike  01/03/2021 18:11  01/03/2021 18:18
# 228495  3AE64EA5BF43CF72  electric_bike  26/03/2021 17:58  26/03/2021 18:06
#
#                   start_station_name start_station_id  \
# ...

# %%
dt_prueba.groupby(['rideable_type','member_casual'])[['ride_id']].count()
# Out:
#                              ride_id
# rideable_type member_casual
# classic_bike  casual           45528
#               member          107017
# docked_bike   casual           15657
# electric_bike casual           22848
#               member           37446

# %%
#para dt2
for i in dt2:
    print(i,dt2[i].isna().sum() )
# Out:
# ride_id 0
# rideable_type 0
# started_at 0
# ended_at 0
# start_station_name 26056
# start_station_id 26056
# end_station_name 28174
# end_station_id 28174
# start_lat 0
# start_lng 0
# end_lat 267
# end_lng 267
# member_casual 0
# ride_length 0
# day_of_week_start 0
# day_of_week_end 0

# %%
dt2_prueba=dt2

# %%
dt2_prueba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337230 entries, 0 to 337229
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             337230 non-null  object
#  1   rideable_type       337230 non-null  object
#  2   started_at          337230 non-null  object
#  3   ended_at            337230 non-null  object
#  4   start_station_name  311174 non-null  object
#  5   start_station_id    311174 non-null  object
#  6   end_station_name    309056 non-null  object
#  7   end_station_id      309056 non-null  object
#  8   start_lat           337230 non-null  float64
#  9   start_lng           337230 non-null  float64
#  10  end_lat             336963 non-null  float64
#  11  end_lng             336963 non-null  float64
#  12  member_casual       337230 non-null  object
#  13  ride_length         337230 non-null  object
#  14  day_of_week_start   337230 non-null  int64
# ...

# %%
dt2_prueba.groupby(['rideable_type'])[['ride_id']].count()/dt2_prueba['rideable_type'].count()
# Out:
#                 ride_id
# rideable_type
# classic_bike   0.636417
# docked_bike    0.073285
# electric_bike  0.290297

# %% [markdown]
# ---

# %% [markdown]
# # Con el de superstore

# %%
filename3="/Users/matiasinostrozacifuentes/Desktop/python_intro/DataScience_Unilever/Semana_2/Data/superstore.csv"
dt_superstore=pd.read_csv(filename3)
dt_superstore
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 2928    2929  US-2017-120390  10/19/2017  10/26/2017  Standard Class
# 2929    2930  CA-2017-143434  11/18/2017  11/24/2017  Standard Class
# 2930    2931  CA-2015-168564    8/8/2015    8/8/2015        Same Day
# 2931    2932  CA-2015-168564    8/8/2015    8/8/2015        Same Day
# 2932    2933  CA-2015-168564    8/8/2015    8/8/2015        Same Day
#
#      Customer ID    Customer Name      Segment        Country  \
# 0       CG-12520      Claire Gute     Consumer  United States
# ...

# %%
dummie=pd.get_dummies(data=dt_superstore, columns = ["Segment"])
dummie.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name        Country             City       State  ...  \
# 0      Claire Gute  United States        Henderson    Kentucky  ...
# 1      Claire Gute  United States        Henderson    Kentucky  ...
# 2  Darrin Van Huff  United States      Los Angeles  California  ...
# 3   Sean O'Donnell  United States  Fort Lauderdale     Florida  ...
# 4   Sean O'Donnell  United States  Fort Lauderdale     Florida  ...
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# ...

# %% [markdown]
# por hacer:
# * filtrar entre 100 dólares y 700 dólares
# * que la columna segment quede en valores numéricos
# * agrupar por categoría
# * cambiar nombre de columnas (todos los títulos en minúsculas)
# * agrupar por descuentos
# * quitar o eliminar si hay NaN o no hay existencia de producto

# %% [markdown]
# 1) Filtrando

# %%
dt_superstore.loc[(dt_superstore['Sales']>100) & (dt_superstore['Sales']<700), :]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 9         10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 13        14  CA-2016-161389   12/5/2016  12/10/2016  Standard Class
# 16        17  CA-2014-105893  11/11/2014  11/18/2014  Standard Class
# 19        20  CA-2014-143336   8/27/2014    9/1/2014    Second Class
# ...      ...             ...         ...         ...             ...
# 2910    2911  CA-2015-118444   11/5/2015   11/9/2015  Standard Class
# 2914    2915  CA-2015-134747  10/12/2015  10/17/2015    Second Class
# 2916    2917  CA-2015-134747  10/12/2015  10/17/2015    Second Class
# 2921    2922  CA-2017-164329   1/30/2017   1/30/2017        Same Day
# 2932    2933  CA-2015-168564    8/8/2015    8/8/2015        Same Day
#
#      Customer ID       Customer Name   Segment        Country           City  \
# ...

# %% [markdown]
# 2) valores numericos columna segment

# %%
dummie=pd.get_dummies(data=dt_superstore, columns = ["Segment"])
dummie.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name        Country             City       State  ...  \
# 0      Claire Gute  United States        Henderson    Kentucky  ...
# 1      Claire Gute  United States        Henderson    Kentucky  ...
# 2  Darrin Van Huff  United States      Los Angeles  California  ...
# 3   Sean O'Donnell  United States  Fort Lauderdale     Florida  ...
# 4   Sean O'Donnell  United States  Fort Lauderdale     Florida  ...
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# ...

# %% [markdown]
# 3) Agrupar por categoria

# %%
dt_superstore.groupby('Category')[['Discount']].count()
# Out:
#                  Discount
# Category
# Furniture             615
# Office Supplies      1776
# Technology            542

# %% [markdown]
# 4) cambiar nombre de columnas (todos los títulos en minúsculas)

# %%
dt_superstore.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
columnas_min=[]
for i in dt_superstore:
    minuscula=i.lower()
    minuscula=minuscula.replace(" ","_")
    columnas_min.append(minuscula)
columnas_min
# Out:
# ['row_id',
#  'order_id',
#  'order_date',
#  'ship_date',
#  'ship_mode',
#  'customer_id',
#  'customer_name',
#  'segment',
#  'country',
#  'city',
#  'state',
#  'postal_code',
#  'region',
#  'product_id',
#  'category',
#  'sub-category',
#  'product_name',
#  'sales',
#  'quantity',
#  'discount',
#  'profit']

# %%
dt_superstore.columns=columnas_min
dt_superstore.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub-category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit'],
#       dtype='object')

# %% [markdown]
# 5) agrupar por descuentos

# %%
dt_superstore.groupby(['Region','Discount']).count()
# Out:
#                   Row ID  Order ID  Order Date  Ship Date  Ship Mode  \
# Region  Discount
# Central 0.00         265       265         265        265        265
#         0.10           5         5           5          5          5
#         0.20         228       228         228        228        228
#         0.30          36        36          36         36         36
#         0.32           6         6           6          6          6
#         0.40           6         6           6          6          6
#         0.50           8         8           8          8          8
#         0.60          35        35          35         35         35
#         0.80          75        75          75         75         75
# East    0.00         450       450         450        450        450
#         0.10          17        17          17         17         17
#         0.20         285       285         285        285        285
# ...

# %% [markdown]
# ) quitando nan

# %%
dt_superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2933 entries, 0 to 2932
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         2933 non-null   int64
#  1   Order ID       2933 non-null   object
#  2   Order Date     2933 non-null   object
#  3   Ship Date      2933 non-null   object
#  4   Ship Mode      2933 non-null   object
#  5   Customer ID    2933 non-null   object
#  6   Customer Name  2933 non-null   object
#  7   Segment        2933 non-null   object
#  8   Country        2933 non-null   object
#  9   City           2933 non-null   object
#  10  State          2933 non-null   object
#  11  Postal Code    2933 non-null   int64
#  12  Region         2933 non-null   object
#  13  Product ID     2933 non-null   object
#  14  Category       2933 non-null   object
#  15  Sub-Category   2933 non-null   object
#  16  Product Name   2933 non-null   object
# ...

# %% [markdown]
# organizando fechas

# %%
#cambiando formato de datos
dt_superstore['order_date'] = pd.to_datetime(dt_superstore['order_date'], format="%m/%d/%Y")
dt_superstore['ship_date'] = pd.to_datetime(dt_superstore['ship_date'], format="%m/%d/%Y")

# %%
dt_superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2933 entries, 0 to 2932
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row_id         2933 non-null   int64
#  1   order_id       2933 non-null   object
#  2   order_date     2933 non-null   datetime64[ns]
#  3   ship_date      2933 non-null   datetime64[ns]
#  4   ship_mode      2933 non-null   object
#  5   customer_id    2933 non-null   object
#  6   customer_name  2933 non-null   object
#  7   segment        2933 non-null   object
#  8   country        2933 non-null   object
#  9   city           2933 non-null   object
#  10  state          2933 non-null   object
#  11  postal_code    2933 non-null   int64
#  12  region         2933 non-null   object
#  13  product_id     2933 non-null   object
#  14  category       2933 non-null   object
#  15  sub-category   2933 non-null   object
#  16  product_name   2933 non-null   object
# ...

# %%
dt_superstore.sort_values(by='order_date')
# Out:
#       row_id        order_id order_date  ship_date       ship_mode  \
# 741      742  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 739      740  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 740      741  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 1759    1760  CA-2014-141817 2014-01-05 2014-01-12  Standard Class
# 593      594  CA-2014-135405 2014-01-09 2014-01-13  Standard Class
# ...      ...             ...        ...        ...             ...
# 645      646  CA-2017-126221 2017-12-30 2018-01-05  Standard Class
# 1297    1298  CA-2017-115427 2017-12-30 2018-01-03  Standard Class
# 1296    1297  CA-2017-115427 2017-12-30 2018-01-03  Standard Class
# 908      909  CA-2017-143259 2017-12-30 2018-01-03  Standard Class
# 907      908  CA-2017-143259 2017-12-30 2018-01-03  Standard Class
#
#      customer_id      customer_name      segment        country  \
# 741     PO-19195      Phillina Ober  Home Office  United States
# ...

# %%
df=pd.read_csv('/Users/matiasinostrozacifuentes/Desktop/python_intro/DataScience_Unilever/Semana_2/Data/Sample - Superstore.csv',encoding='windows-1254') #se le agrega eso porque esta guardado en linux 
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# ---

# %%
code='/Users/matiasinostrozacifuentes/Desktop/python_intro/DataScience_Unilever/Semana_2/Data/heart_2020_cleaned.csv'
