# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
filename = "/Users/matiasinostrozacifuentes/Desktop/python_intro/DataScience_Unilever/Semana_3/Data/diabetes.csv"
df = pd.read_csv(filename)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
filter_bmi1= df.loc[:,"BMI"] >=19

# %%
filter_bmi2= df.loc[:,"BMI"]<=35

# %%
df1=df

# %%
df1 = df1 [filter_bmi1 & filter_bmi2]

# %%
df1.iloc[:,5].min()
# Out:
# 19.1

# %%
df1["BloodPressure"].value_counts()
# Out:
# 74     40
# 70     38
# 64     32
# 68     32
# 72     31
# 60     30
# 62     29
# 80     27
# 78     26
# 66     22
# 58     21
# 0      19
# 76     18
# 82     15
# 90     13
# 86     13
# 56     12
# 50     12
# 88     11
# 84     11
# 54     10
# 52      7
# 92      4
# 75      4
# 65      4
# 48      3
# 96      3
# 44      3
# 85      3
# 55      2
# 98      2
# 46      2
# 94      2
# 122     1
# 95      1
# 102     1
# 61      1
# 104     1
# 110     1
# 24      1
# 38      1
# Name: BloodPressure, dtype: int64

# %%
filter3=df1["BloodPressure"]>=60

# %%
filter4=df1["BloodPressure"]<=110

# %%
df1 =df1[filter3&filter4]

# %%
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
plt.bar('Age','BMI',data=df)
plt.show()

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
intervalos=range(min(df['Age']),max(df['Age']))
plt.hist(x=df['Age'],bins=intervalos,color='#F2AB6D', rwidth=0.85)
plt.title('cantidad de examenes por edad')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
plt.show()

# %%
positivos = df['Outcome'] ==1 
dfpositivo = df.loc[positivos, :]
dfpositivo
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome  Casos_confirmados
# ...

# %%
plt.figure(dpi=100)
plt.title('Años')
plt.hist(x = df['Age'])
plt.hist(x = dfpositivo['Age'])
plt.grid(True)
plt.show()
plt.clf()
