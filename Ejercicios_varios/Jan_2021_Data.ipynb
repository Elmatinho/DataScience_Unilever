# %%
#Import pandas , csv 
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv('/Users/matiasinostrozacifuentes/Desktop/python_intro/DataScience_Unilever/Ejercicios_varios/Jan 2021 Data - Viz5 Gender Inequality and HIVAIDS.csv',encoding='windows-1254')

# %%
#Info del documento
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2640 entries, 0 to 2639
# Data columns (total 10 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Country                                                                         2640 non-null   object
#  1   UNICEF Region                                                                   2640 non-null   object
#  2   Year                                                                            2640 non-null   int64
#  3   Sex                                                                             2640 non-null   object
#  4   Age                                                                             2640 non-null   object
#  5   Estimated incidence rate of new HIV infection per 1 000 uninfected population   2520 non-null   float64
# ...

# %%
df
# Out:
#        Country                UNICEF Region  Year     Sex        Age  \
# 0       Angola  Eastern and Southern Africa  1990  Female  Age 10-19
# 1       Angola  Eastern and Southern Africa  1990    Male  Age 10-19
# 2       Angola  Eastern and Southern Africa  1991  Female  Age 10-19
# 3       Angola  Eastern and Southern Africa  1991    Male  Age 10-19
# 4       Angola  Eastern and Southern Africa  1992  Female  Age 10-19
# ...        ...                          ...   ...     ...        ...
# 2635  Zimbabwe  Eastern and Southern Africa  2017    Male  Age 10-19
# 2636  Zimbabwe  Eastern and Southern Africa  2018  Female  Age 10-19
# 2637  Zimbabwe  Eastern and Southern Africa  2018    Male  Age 10-19
# 2638  Zimbabwe  Eastern and Southern Africa  2019  Female  Age 10-19
# 2639  Zimbabwe  Eastern and Southern Africa  2019    Male  Age 10-19
#
#       Estimated incidence rate of new HIV infection per 1 000 uninfected population   \
# ...

# %%
#Describiendo todas las columnas de un DataFrame independientemente del tipo de datos.
df.describe(include='all')
# Out:
#        Country                UNICEF Region         Year     Sex        Age  \
# count     2640                         2640  2640.000000    2640       2640
# unique      44                            2          NaN       2          1
# top     Angola  Eastern and Southern Africa          NaN  Female  Age 10-19
# freq        60                         1320          NaN    1320       2640
# mean       NaN                          NaN  2004.500000     NaN        NaN
# std        NaN                          NaN     8.657081     NaN        NaN
# min        NaN                          NaN  1990.000000     NaN        NaN
# 25%        NaN                          NaN  1997.000000     NaN        NaN
# 50%        NaN                          NaN  2004.500000     NaN        NaN
# 75%        NaN                          NaN  2012.000000     NaN        NaN
# max        NaN                          NaN  2019.000000     NaN        NaN
#
# ...

# %%
#Pandas elimina filas con valores NaN para cualquier columna usando el método DataFrame.dropna()
df = df.dropna()
print("DataFrame after removing rows with NaN value in any column:")
print(df)
# Out:
# DataFrame after removing rows with NaN value in any column:
#        Country                UNICEF Region  Year     Sex        Age  \
# 0       Angola  Eastern and Southern Africa  1990  Female  Age 10-19
# 1       Angola  Eastern and Southern Africa  1990    Male  Age 10-19
# 2       Angola  Eastern and Southern Africa  1991  Female  Age 10-19
# 3       Angola  Eastern and Southern Africa  1991    Male  Age 10-19
# 4       Angola  Eastern and Southern Africa  1992  Female  Age 10-19
# ...        ...                          ...   ...     ...        ...
# 2635  Zimbabwe  Eastern and Southern Africa  2017    Male  Age 10-19
# 2636  Zimbabwe  Eastern and Southern Africa  2018  Female  Age 10-19
# 2637  Zimbabwe  Eastern and Southern Africa  2018    Male  Age 10-19
# 2638  Zimbabwe  Eastern and Southern Africa  2019  Female  Age 10-19
# 2639  Zimbabwe  Eastern and Southern Africa  2019    Male  Age 10-19
#
# ...

# %%
#Eliminar los duplicados
df.duplicated()
# Out:
# Country
# Angola      False
# Angola      False
# Angola      False
# Angola      False
# Angola      False
#             ...
# Zimbabwe    False
# Zimbabwe    False
# Zimbabwe    False
# Zimbabwe    False
# Zimbabwe    False
# Length: 2460, dtype: bool

# %%
df = df.drop_duplicates()
df
# Out:
#                         UNICEF Region  Year     Sex        Age  \
# Country
# Angola    Eastern and Southern Africa  1990  Female  Age 10-19
# Angola    Eastern and Southern Africa  1990    Male  Age 10-19
# Angola    Eastern and Southern Africa  1991  Female  Age 10-19
# Angola    Eastern and Southern Africa  1991    Male  Age 10-19
# Angola    Eastern and Southern Africa  1992  Female  Age 10-19
# ...                               ...   ...     ...        ...
# Zimbabwe  Eastern and Southern Africa  2017    Male  Age 10-19
# Zimbabwe  Eastern and Southern Africa  2018  Female  Age 10-19
# Zimbabwe  Eastern and Southern Africa  2018    Male  Age 10-19
# Zimbabwe  Eastern and Southern Africa  2019  Female  Age 10-19
# Zimbabwe  Eastern and Southern Africa  2019    Male  Age 10-19
#
#           Estimated incidence rate of new HIV infection per 1 000 uninfected population   \
# Country
# Angola                                                 0.64
# ...

# %%
df['Sex'].value_counts()
# Out:
# Female    1230
# Male      1230
# Name: Sex, dtype: int64

# %%
#Aplicando filtros
data ={'Country':['Angola', 'Angola', 'Angola', 'Angola','Angola','Zimbabwe','Zimbabwe','Zimbabwe','Zimbabwe','Zimbabwe'],
      'Year':['1990','1990','1991','1991','1992','2017','2018','2018','2019','2019'],
      'Estimated_number_of_annual_new_HIV_infections':[500.0, 100.0, 500.0, 200.0,590.0,1200.0,4400.0,1100.0,4400.0,1100.0],
      'Sex':['Female','Male','Female','Male','Female','Male','Female','Male','Female','Male'],
      'Age':['Age 10-19','Age 10-19','Age 10-19','Age 10-19','Age 10-19','Age 10-19','Age 10-19','Age 10-19','Age 10-19','Age 10-19']}


df = pd.DataFrame(data,columns=['Country','Year','Estimated_number_of_annual_new_HIV_infections','Sex','Age'])
df['Age']= df['Age'].replace(['Age 10-19','Age 10-19','Age 10-19','Age 10-19','Age 10-19','Age 10-19','Age 10-19','Age 10-19','Age 10-19','Age 10-19'],'Age_10-19')
print(df)
# Out:
#     Country  Year  Estimated_number_of_annual_new_HIV_infections     Sex  \
# 0    Angola  1990                                          500.0  Female
# 1    Angola  1990                                          100.0    Male
# 2    Angola  1991                                          500.0  Female
# 3    Angola  1991                                          200.0    Male
# 4    Angola  1992                                          590.0  Female
# 5  Zimbabwe  2017                                         1200.0    Male
# 6  Zimbabwe  2018                                         4400.0  Female
# 7  Zimbabwe  2018                                         1100.0    Male
# 8  Zimbabwe  2019                                         4400.0  Female
# 9  Zimbabwe  2019                                         1100.0    Male
#
#          Age
# 0  Age_10-19
# 1  Age_10-19
# 2  Age_10-19
# 3  Age_10-19
# 4  Age_10-19
# 5  Age_10-19
# 6  Age_10-19
# 7  Age_10-19
# 8  Age_10-19
# 9  Age_10-19

# %%
df[df['Estimated_number_of_annual_new_HIV_infections']>0][['Sex','Age']]
# Out:
#       Sex        Age
# 0  Female  Age_10-19
# 1    Male  Age_10-19
# 2  Female  Age_10-19
# 3    Male  Age_10-19
# 4  Female  Age_10-19
# 5    Male  Age_10-19
# 6  Female  Age_10-19
# 7    Male  Age_10-19
# 8  Female  Age_10-19
# 9    Male  Age_10-19

# %%
df.pivot_table('Estimated_number_of_annual_new_HIV_infections', index='Sex', columns='Age')
# Out:
# Age     Age_10-19
# Sex
# Female     2078.0
# Male        740.0

# %%
#dispersion
data ={'Country':['Angola', 'Angola', 'Angola', 'Angola','Angola','Zimbabwe','Zimbabwe','Zimbabwe','Zimbabwe','Zimbabwe'],
      'Year':['1990','1990','1991','1991','1992','2017','2018','2018','2019','2019'],
      'Estimated_number_of_annual_new_HIV_infections':[500.0, 100.0, 500.0, 200.0,590.0,1200.0,4400.0,1100.0,4400.0,1100.0],
      'Sex':['Female','Male','Female','Male','Female','Male','Female','Male','Female','Male'],
      'Age':['Age 10-19','Age 10-19','Age 10-19','Age 10-19','Age 10-19','Age 10-19','Age 10-19','Age 10-19','Age 10-19','Age 10-19']}


scatter_plot=df.plot.scatter(x='Estimated_number_of_annual_new_HIV_infections',y='Sex',c="magenta")
scatter_plot.plot()
plt.show()

# %%
x=np.random.randn(100)
y=np.random.randn(100)
fig, ax=plt.subplots()
ax.scatter(x,y,c='purple')
plt.show()

# %%
plt.figure()                                
ax = plt.subplot(1, 3, 1)                   
plt.title('Personas')                          
ax.set_xticks(Estimated_number_of_annual_new_HIV_infections)                    
ax.set_xticklabels(Estimated_number_of_annual_new_HIV_infections, rotation=60)  
ax.set_xlabel('Estimated_number_of_annual_new_HIV_infections')            
ax.set_ylabel('Sex')
# Out:
# Text(0, 0.5, 'Sex')

# %%
def cambiodevalores(columna):    
    c=[]
    for i in range(len(columna)):
        x = 'Age 10*19'
        c.append(x)
    columna=c
    return columna

# %%
df['Age']=cambiodevalores(df['Age'])

# %%
df
# Out:
#        Country                UNICEF Region  Year     Sex        Age  \
# 0       Angola  Eastern and Southern Africa  1990  Female  Age 10*19
# 1       Angola  Eastern and Southern Africa  1990    Male  Age 10*19
# 2       Angola  Eastern and Southern Africa  1991  Female  Age 10*19
# 3       Angola  Eastern and Southern Africa  1991    Male  Age 10*19
# 4       Angola  Eastern and Southern Africa  1992  Female  Age 10*19
# ...        ...                          ...   ...     ...        ...
# 2635  Zimbabwe  Eastern and Southern Africa  2017    Male  Age 10*19
# 2636  Zimbabwe  Eastern and Southern Africa  2018  Female  Age 10*19
# 2637  Zimbabwe  Eastern and Southern Africa  2018    Male  Age 10*19
# 2638  Zimbabwe  Eastern and Southern Africa  2019  Female  Age 10*19
# 2639  Zimbabwe  Eastern and Southern Africa  2019    Male  Age 10*19
#
#       Estimated incidence rate of new HIV infection per 1 000 uninfected population   \
# ...

# %%
df['Age'].replace(to_replace='Age 10*19',value='Age 10-19')
# Out:
# 0       Age 10-19
# 1       Age 10-19
# 2       Age 10-19
# 3       Age 10-19
# 4       Age 10-19
#           ...
# 2635    Age 10-19
# 2636    Age 10-19
# 2637    Age 10-19
# 2638    Age 10-19
# 2639    Age 10-19
# Name: Age, Length: 2640, dtype: object
