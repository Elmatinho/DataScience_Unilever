# %% [markdown]
# # Para hoy
# * Establecer el tipo y los colores en los marcadores
# * Matlab style v/s sintaxis del objeto

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# Multiples lineas en un gráfico
# La idea es que cada linea tenga su propia leyenda y su propio color
# ademas de puntos diferentes
#
# ---
# Lineas random
# usar t=arange(donde empiezo, donde termino, cuanto incremento)
#
# plt.figure(dpi=100)-> tamaño
# plt.plot(x primera curva,y primera curva,parametro primera curva, x segunda curva, y segunda curva, ...., hasta n)
# plt.axis([parte inferior x, parte superior x, parte inferior y, parte superior y])

# %%
from numpy import sin,arange,pi,cos
x=arange(0.0,2*pi,0.1)
z=cos(x)
y=sin(x)
plt.plot(x,y,'b-',x,z,'r-')
plt.grid(axis='y')
plt.axis([0,6,-1,1])
plt.show()

# %%
bancos_filename='/Users/matiasinostrozacifuentes/Desktop/python_intro/DataScience_Unilever/Semana_3/Data/bancos.csv'
df_bancos=pd.read_csv(bancos_filename)
df_bancos
# Out:
#             Empresa       Fecha  Apertura  Máximo  Mínimo  Cierre   Volumen
# 0    Banco Sabadell  2021-04-01    0.4591  0.4591  0.4445  0.4553  30084389
# 1    Banco Sabadell  2021-04-06    0.4630  0.4778  0.4581  0.4656  44336977
# 2    Banco Sabadell  2021-04-07    0.4650  0.4705  0.4626  0.4673  22517116
# 3    Banco Sabadell  2021-04-08    0.4662  0.4695  0.4536  0.4607  30800345
# 4    Banco Sabadell  2021-04-09    0.4607  0.4644  0.4512  0.4600  35703383
# ..              ...         ...       ...     ...     ...     ...       ...
# 97        Caixabank  2021-04-26    2.5000  2.5530  2.4670  2.5470  18930563
# 98        Caixabank  2021-04-27    2.5600  2.6170  2.5270  2.6060  11769775
# 99        Caixabank  2021-04-28    2.6200  2.6430  2.5770  2.6170  11811235
# 100       Caixabank  2021-04-29    2.6290  2.6860  2.6030  2.6570  15696456
# 101       Caixabank  2021-04-30    2.6550  2.6850  2.6400  2.6670  11391476
#
# [102 rows x 7 columns]

# %%
df_bancos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102 entries, 0 to 101
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Empresa   102 non-null    object
#  1   Fecha     102 non-null    datetime64[ns]
#  2   Apertura  102 non-null    float64
#  3   Máximo    102 non-null    float64
#  4   Mínimo    102 non-null    float64
#  5   Cierre    102 non-null    float64
#  6   Volumen   102 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 6.4+ KB

# %%
df_bancos['Empresa'].unique()
# Out:
# array(['Banco Sabadell', 'Banco Santander', 'Bankinter', 'BBVA',
#        'Caixabank'], dtype=object)

# %%
df_bancos=df_bancos.sort_values(by='Fecha')

# %%
df_bancos['Promedio']=(df_bancos['Máximo']+df_bancos['Mínimo'])/2
df_bancos
# Out:
#              Empresa      Fecha  Apertura  Máximo  Mínimo  Cierre    Volumen  \
# 0     Banco Sabadell 2021-04-01    0.4591  0.4591  0.4445  0.4553   30084389
# 20   Banco Santander 2021-04-01    3.3900  3.4300  3.3800  3.4200    2141100
# 61              BBVA 2021-04-01    5.2400  5.2600  5.2100  5.2500    1612300
# 41         Bankinter 2021-04-01    5.9000  5.9000  5.7640  5.8520    2203169
# 82         Caixabank 2021-04-01    2.6000  2.6020  2.5620  2.6000   36653487
# ..               ...        ...       ...     ...     ...     ...        ...
# 19    Banco Sabadell 2021-04-30    0.4900  0.5290  0.4874  0.5274  111247189
# 60         Bankinter 2021-04-30    4.5990  4.6460  4.5570  4.5570    5440366
# 81              BBVA 2021-04-30    5.6700  5.6900  5.5900  5.6000    2050400
# 40   Banco Santander 2021-04-30    3.8200  3.8400  3.8000  3.8100    4689000
# 101        Caixabank 2021-04-30    2.6550  2.6850  2.6400  2.6670   11391476
#
#      Promedio del día  Promedio
# ...

# %%
filtro_santander=df_bancos.loc[df_bancos['Empresa']=='Banco Santander', :]
filtro_sabadell=df_bancos.loc[df_bancos['Empresa']=='Banco Sabadell', :]
filtro_bankinter=df_bancos.loc[df_bancos['Empresa']=='Bankinter', :]
filtro_bbva=df_bancos.loc[df_bancos['Empresa']=='BBVA', :]
filtro_caixabank=df_bancos.loc[df_bancos['Empresa']=='Caixabank', :]

# %%
filtro_bankinter
# Out:
#       Empresa      Fecha  Apertura  Máximo  Mínimo  Cierre   Volumen  \
# 41  Bankinter 2021-04-01     5.900   5.900   5.764   5.852   2203169
# 42  Bankinter 2021-04-06     5.866   5.932   5.802   5.802   2034249
# 43  Bankinter 2021-04-07     5.802   5.860   5.734   5.848   3149916
# 44  Bankinter 2021-04-08     5.874   5.896   5.760   5.876   2209946
# 45  Bankinter 2021-04-09     5.882   5.896   5.828   5.852   1144539
# 46  Bankinter 2021-04-12     5.858   5.876   5.790   5.832   1647126
# 47  Bankinter 2021-04-13     5.870   5.940   5.748   5.804   2996279
# 48  Bankinter 2021-04-14     5.820   5.838   5.754   5.830   1968295
# 49  Bankinter 2021-04-15     5.838   5.904   5.714   5.714   2844106
# 50  Bankinter 2021-04-16     5.754   5.824   5.736   5.800   4852141
# 51  Bankinter 2021-04-19     5.814   5.938   5.782   5.892   2284461
# 52  Bankinter 2021-04-20     5.896   5.900   5.640   5.640   3389111
# 53  Bankinter 2021-04-21     5.700   5.744   5.520   5.600   4662438
# ...

# %%
plt.figure(dpi=100)
plt.plot(filtro_sabadell['Fecha'],filtro_sabadell['Cierre'],'r.-',filtro_santander['Fecha'],filtro_santander['Cierre'],'b--',filtro_bankinter['Fecha'],filtro_bankinter['Cierre'],'go-',filtro_bbva['Fecha'],filtro_bbva['Cierre'],'c',
filtro_caixabank['Fecha'],filtro_caixabank['Cierre'],'yo-')
plt.show()

# %%
plt.figure(dpi=100)
plt.plot(filtro_sabadell['Fecha'].dt.day,filtro_sabadell['Promedio'],'r.-',filtro_santander['Fecha'].dt.day,filtro_santander['Promedio'],'b--',filtro_bankinter['Fecha'].dt.day,filtro_bankinter['Promedio'],'g^-',filtro_bbva['Fecha'].dt.day,filtro_bbva['Promedio'],'c',
filtro_caixabank['Fecha'].dt.day,filtro_caixabank['Promedio'],'yo-')
plt.show()

# %% [markdown]
# # Extrayendo la fecha derechito

# %%
df_bancos['Day']=df_bancos['Fecha'].dt.day

# %%
df_bancos
# Out:
#              Empresa      Fecha  Apertura  Máximo  Mínimo  Cierre    Volumen  \
# 0     Banco Sabadell 2021-04-01    0.4591  0.4591  0.4445  0.4553   30084389
# 20   Banco Santander 2021-04-01    3.3900  3.4300  3.3800  3.4200    2141100
# 61              BBVA 2021-04-01    5.2400  5.2600  5.2100  5.2500    1612300
# 41         Bankinter 2021-04-01    5.9000  5.9000  5.7640  5.8520    2203169
# 82         Caixabank 2021-04-01    2.6000  2.6020  2.5620  2.6000   36653487
# ..               ...        ...       ...     ...     ...     ...        ...
# 19    Banco Sabadell 2021-04-30    0.4900  0.5290  0.4874  0.5274  111247189
# 60         Bankinter 2021-04-30    4.5990  4.6460  4.5570  4.5570    5440366
# 81              BBVA 2021-04-30    5.6700  5.6900  5.5900  5.6000    2050400
# 40   Banco Santander 2021-04-30    3.8200  3.8400  3.8000  3.8100    4689000
# 101        Caixabank 2021-04-30    2.6550  2.6850  2.6400  2.6670   11391476
#
#      Promedio del día  Promedio  Day
# ...

# %% [markdown]
# ---
# # Cosas de la plataforma

# %%
filename='/Users/matiasinostrozacifuentes/Desktop/python_intro/DataScience_Unilever/Semana_3/Data/athleteEventsNoPersonal.csv'
base=pd.read_csv(filename)

# %%
base
# Out:
#            ID   Age  Height         Team  NOC        Games  Year  Season  \
# 0           5  21.0   185.0  Netherlands  NED  1988 Winter  1988  Winter
# 1           5  21.0   185.0  Netherlands  NED  1988 Winter  1988  Winter
# 2           5  25.0   185.0  Netherlands  NED  1992 Winter  1992  Winter
# 3           5  25.0   185.0  Netherlands  NED  1992 Winter  1992  Winter
# 4           5  27.0   185.0  Netherlands  NED  1994 Winter  1994  Winter
# ...       ...   ...     ...          ...  ...          ...   ...     ...
# 40611  135567  28.0   183.0       Russia  RUS  2004 Summer  2004  Summer
# 40612  135570  27.0   176.0       Poland  POL  2014 Winter  2014  Winter
# 40613  135570  27.0   176.0       Poland  POL  2014 Winter  2014  Winter
# 40614  135571  30.0   185.0       Poland  POL  1998 Winter  1998  Winter
# 40615  135571  34.0   185.0       Poland  POL  2002 Winter  2002  Winter
#
#                  City          Sport  \
# 0             Calgary  Speed Skating
# ...

# %%
valorUnico=base.groupby(['Year'])['ID'].nunique(
)
valorUnico
# Out:
# Year
# 1896      26
# 1900     178
# 1904      91
# 1906     125
# 1908     312
# 1912     347
# 1920     392
# 1924     537
# 1928     550
# 1932     336
# 1936     771
# 1948     756
# 1952     877
# 1956     595
# 1960     901
# 1964     885
# 1968     973
# 1972    1210
# 1976    1086
# 1980     968
# 1984    1190
# 1988    1527
# 1992    1693
# 1994     290
# 1996    1512
# 1998     343
# 2000    1611
# 2002     369
# 2004    1598
# 2006     376
# 2008    1672
# 2010     374
# 2012    1597
# 2014     429
# 2016    1692
# Name: ID, dtype: int64

# %%
plt.plot(valorUnico.index,valorUnico.values,marker='.',markersize=10)
plt.ylabel('Cantidad de deportistas')
plt.xlabel('Años')
plt.title('Deportistas olimpicos por año')
plt.show()

# %% [markdown]
# # Forma orientada a los objetos

# %%
fig, axes=plt.subplots(nrows = 1 , ncols = 1);

axes.plot(valorUnico.index,valorUnico.values,c='c');
plt.xticks(fontsize = 14);
plt.yticks(fontsize = 25);

# %% [markdown]
# # Multiples graficos

# %%
name='/Users/matiasinostrozacifuentes/Desktop/python_intro/DataScience_Unilever/Semana_3/Data/linearRegPredicted.csv'
predictions=pd.read_csv(name)
predictions
# Out:
#        feature      actual   predicted
# 0     0.000000  -51.000000  -50.991193
# 1    25.000000  -12.000000  -11.399052
# 2   117.583220  134.907414  135.223663
# 3   108.922466  134.085179  121.507752
# 4    96.839983  114.530638  102.372896
# ..         ...         ...         ...
# 89  120.740859  133.922297  140.224371
# 90  100.179788  126.827116  107.662098
# 91   59.333765   50.257797   42.974839
# 92  120.157757  144.754676  139.300920
# 93  115.539152  120.697309  131.986503
#
# [94 rows x 3 columns]

# %%
features=predictions['feature'].values
actual=predictions['actual'].values
predicted=predictions['predicted'].values

# %%
plt.plot(features, predicted, c = 'r', label = 'Prediction')
plt.scatter(features, actual, c= 'k', label = 'Actual')
plt.legend(loc=(1.02,0))
plt.tight_layout() #con esto se guarda la leyenda
plt.savefig('MATLABSavedPlot.png', dpi = 300)
